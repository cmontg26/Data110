# %% [markdown]
# <a href="https://colab.research.google.com/github/cmontg26/Data110/blob/main/Week2_Candace_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Anscombe's Quartet:
x = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y1 = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]
y2 = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]
y3 = [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]
x4 = [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8]
y4 = [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]

# %%
plt.scatter(x, y1)

# %%
# Calculate the slope (m) and intercept (b) of the line using np.polyfit
m, b = np.polyfit(x, y1, 1)

# Create the regression line
regression_line = m * np.array(x) + b

# Plot the data points and regression line
plt.scatter(x, y1)
plt.plot(x, regression_line,color='red')
plt.xlabel('x')
plt.ylabel('y1')
# Out:
# Text(0, 0.5, 'y1')

# %%
# Calculate the slope (m) and intercept (b) of the line using np.polyfit
m, b = np.polyfit(x, y2, 1)

# Create the regression line
regression_line = m * np.array(x) + b

# Plot the data points and regression line
plt.scatter(x, y2)
plt.plot(x, regression_line,color='green')
plt.xlabel('x')
plt.ylabel('y2')
# Out:
# Text(0, 0.5, 'y2')

# %%
# Calculate the slope (m) and intercept (b) of the line using np.polyfit
m, b = np.polyfit(x, y3, 1)

# Create the regression line
regression_line = m * np.array(x) + b

# Plot the data points and regression line
plt.scatter(x, y3)
plt.plot(x, regression_line,color='pink')
plt.xlabel('x')
plt.ylabel('y3')
# Out:
# Text(0, 0.5, 'y3')

# %%
# Calculate the slope (m) and intercept (b) of the line using np.polyfit
m, b = np.polyfit(x, x4, 1)

# Create the regression line
regression_line = m * np.array(x) + b

# Plot the data points and regression line
plt.scatter(x, x4)
plt.plot(x, regression_line,color='blue')
plt.xlabel('x')
plt.ylabel('x4')
# Out:
# Text(0, 0.5, 'x4')

# %%
# Calculate the slope (m) and intercept (b) of the line using np.polyfit
m, b = np.polyfit(x, y4, 1)

# Create the regression line
regression_line = m * np.array(x) + b

# Plot the data points and regression line
plt.scatter(x, y4)
plt.plot(x, regression_line,color='orange')
plt.xlabel('x')
plt.ylabel('y4')
# Out:
# Text(0, 0.5, 'y4')

# %% [markdown]
# # **Reflection Questions:**
#
# ___
# ### 1. How do the datasets visually differ despite having similar summary statistics?
# *Each dataset has 11 numbers and has an average of 7.50 with the x, x4 having an average of 9.00. The slopes for **y1, y2, and y3** all slope up but the point distribution is varied with y2 having a almost bell shaped distribution. Due to the outliers in **x4 and y4** the slopes start high and decline.*
#
# ### 2. How did the outlier in the x4, y4 dataset affect the regression line compared to the other datasets?
# *The outliers cause the slope to change downward because they are so much higher than the rest of the data set. While outliers can be misleading, there  are more aggressive regression techniques like Huber Regression.*
#
# ### 3. Why is it important to visualize data in addition to calculating summary statistics?
# *Data visualizations helped to identify the outliers in x4 and y4 and changes in the slope. Being able to identify the anomalies/outliers and the trending patterns would better inform any decision maker using the data.  *
