# %% [markdown]
# <a href="https://colab.research.google.com/github/cmontg26/Data110/blob/main/Candace_Week_2_in_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Let's add some libraries.

# %%
# matplot is for data visualizations
import matplotlib.pyplot as plt
# numpy is for working with array, numerical calculation
import numpy as np
# pandas is for dataframe
import pandas as pd

# %% [markdown]
# Now, we need to add dataset

# %%
df=pd.read_csv('/content/Pipeline Packaging Clearance List - August 2025.csv')

# %%
df
# Out:
#        Unnamed: 0                                  Unnamed: 1  \
# 0    Product Code                            Product Category
# 1           61012      Bottles > Glass Bottles > Boston Round
# 2           68356        Bottles > Plastic Bottles > Beverage
# 3           68043  Bottles > Plastic Bottles > Bullet / Cosmo
# 4           68083  Bottles > Plastic Bottles > Bullet / Cosmo
# ..            ...                                         ...
# 195         91108                           Tools > Component
# 196        521874                                Tubs > Cover
# 197         63063                                Tubs > Round
# 198        512030                                Tubs > Round
# 199         61269                         Vials > Glass Vials
#
#                           Clearance List - August 2025  \
# 0                                          Description
# 1                2 OZ_AMBER__BOSTON ROUND_20-400_@288_
# ...

# %%
ds=pd.read_csv('https://raw.githubusercontent.com/cmontg26/Data110-21843--fall25/refs/heads/main/dataset/happiness.csv')

# %%
ds.head()
# Out:
#        country  Rank  Happiness Score  Life Ladder  Log GDP per capita  \
# 0      Denmark     1            7.693     7.519909           10.699571
# 1       Norway     2            7.655     7.678277           11.050944
# 2  Switzerland     3            7.650     7.776209           10.935776
# 3  Netherlands     4            7.512     7.470716           10.723517
# 4       Sweden     5            7.480     7.560148           10.676098
#
#    Social support  Healthy life expectancy at birth  \
# 0        0.951437                         70.044815
# 1        0.947657                         70.524834
# 2        0.946864                         72.734001
# 3        0.938885                         71.091934
# 4        0.929397                         71.740868
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                      0.932628    0.127539                   0.187408
# 1                      0.946566    0.120922                   0.368043
# ...

# %%
ds.tail()
# Out:
#       country  Rank  Happiness Score  Life Ladder  Log GDP per capita  \
# 137   Comoros   138            3.851     3.955640            7.259981
# 138    Guinea   139            3.847     3.651555            7.429011
# 139  Tanzania   140            3.770     4.006897            7.708783
# 140    Rwanda   141            3.715     3.333048            7.318347
# 141     Benin   142            3.528     3.193469            7.526094
#
#      Social support  Healthy life expectancy at birth  \
# 137        0.719218                         53.497059
# 138        0.542295                         48.798191
# 139        0.832056                         53.267857
# 140        0.637147                         54.860779
# 141        0.523027                         50.676147
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 137                      0.534041   -0.069553                   0.651009
# ...

# %%
ds.head(10)
# Out:
#        country  Rank  Happiness Score  Life Ladder  Log GDP per capita  \
# 0      Denmark     1            7.693     7.519909           10.699571
# 1       Norway     2            7.655     7.678277           11.050944
# 2  Switzerland     3            7.650     7.776209           10.935776
# 3  Netherlands     4            7.512     7.470716           10.723517
# 4       Sweden     5            7.480     7.560148           10.676098
# 5       Canada     6            7.477     7.415144           10.640521
# 6      Finland     7            7.389     7.420209           10.594456
# 7      Austria     8            7.369     7.400689           10.705052
# 8      Iceland     9            7.355     7.590660           10.589972
# 9    Australia    10            7.350     7.195586           10.658696
#
#    Social support  Healthy life expectancy at birth  \
# 0        0.951437                         70.044815
# 1        0.947657                         70.524834
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 20 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   country                                                   142 non-null    object
#  1   Rank                                                      142 non-null    int64
#  2   Happiness Score                                           142 non-null    float64
#  3   Life Ladder                                               142 non-null    float64
#  4   Log GDP per capita                                        139 non-null    float64
#  5   Social support                                            142 non-null    float64
#  6   Healthy life expectancy at birth                          140 non-null    float64
#  7   Freedom to make life choices                              141 non-null    float64
# ...

# %%
ds.describe()
# Out:
#              Rank  Happiness Score  Life Ladder  Log GDP per capita  \
# count  142.000000       142.000000   142.000000          139.000000
# mean    71.500000         5.467239     5.443751            9.277067
# std     41.135953         1.087999     1.116592            1.149919
# min      1.000000         3.528000     3.164491            6.481236
# 25%     36.250000         4.613750     4.603896            8.409574
# 50%     71.500000         5.346500     5.336502            9.419761
# 75%    106.750000         6.284750     6.210948           10.156146
# max    142.000000         7.693000     7.776209           11.738482
#
#        Social support  Healthy life expectancy at birth  \
# count      142.000000                        140.000000
# mean         0.809077                         62.710796
# std          0.112769                          7.338667
# min          0.510575                         44.032639
# 25%          0.743069                         57.917182
# ...

# %%
plt.scatter(ds['Rank'],ds['Happiness Score'])

# %%
plt.figure(figsize=(10,5))
plt.scatter(ds['Rank'],ds['Happiness Score'])

# %%
plt.figure(figsize=(10,5))
plt.scatter(ds['Rank'],ds['Happiness Score'])
plt.xlabel('Rank')
plt.ylabel('Happiness Score')
plt.title('Happiness Score vs Rank')
# Out:
# Text(0.5, 1.0, 'Happiness Score vs Rank')

# %%
plt.figure(figsize=(10,5))
plt.scatter(ds['Rank'],ds['Happiness Score'],color='pink',marker='*')
plt.xlabel('Rank')
plt.ylabel('Happiness Score')
plt.title('Happiness Score vs Rank')
# Out:
# Text(0.5, 1.0, 'Happiness Score vs Rank')

# %%
plt.figure(figsize=(10,5))
plt.scatter(ds['Rank'],ds['Happiness Score'],color='green',marker='*')
plt.xlabel('Rank')
plt.ylabel('Happiness Score')
plt.title('Happiness Score vs Rank')
plt.grid(True)

# %% [markdown]
# m, b=np.polyfit(x,y1.1), # m is slope while b = y-intercept. Plot s for continous function
