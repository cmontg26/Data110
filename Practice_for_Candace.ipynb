# %% [markdown]
# <a href="https://colab.research.google.com/github/cmontg26/Data110/blob/main/Practice_for_Candace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

days = np.arange(1, 31)
prices = 100 + np.cumsum(np.random.randn(30))

plt.plot(days, prices, marker='o', linestyle='-', color='green')
plt.title("Simulated Stock Price")
plt.xlabel("Day")
plt.ylabel("Price ($)")
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# To see available colormaps in matplotlib (used by seaborn):
print(plt.colormaps())
# Out:
# ['magma', 'inferno', 'plasma', 'viridis', 'cividis', 'twilight', 'twilight_shifted', 'turbo', 'berlin', 'managua', 'vanimo', 'Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c', 'grey', 'gist_grey', 'gist_yerg', 'Grays', 'magma_r', 'inferno_r', 'plasma_r', 'viridis_r', 'cividis_r', 'twilight_r', 'twilight_shifted_r', 
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# 1. Prepare your data
# For demonstration, Create a sample correlation matrix
data = np.random.rand(10, 10) # Generate random data
df = pd.DataFrame(data, columns=[f'Col_{i}' for i in range(10)],
                  index=[f'Row_{i}' for i in range(10)])

# df = sns.load_dataset("flights").pivot_table(index="month", columns="year", values="passengers")
# correlation_matrix = df.corr()

# 2. Create the heatmap
plt.figure(figsize=(8, 6)) # Adjust figure size as needed
sns.heatmap(df, annot=True, cmap='inferno', fmt=".2f", linewidths=.5)
# - annot=True displays the data values on the heatmap
# - cmap sets the color map
# - fmt=".2f" formats the annotations to two decimal places
# - linewidths adds lines between cells

# 3. Add titles and labels
plt.title('Heatmap for Practice')
plt.xlabel('Columns')
plt.ylabel('Rows')

# 4. Display the heatmap
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
plt.style.use("ggplot")  # Sets the style for the plots

# %%
x = ['a','b','c','d']
y = [10,8,12,16]

plt.bar(x,y, label='Week 1')
plt.legend()
plt.show()

# %%
from pywaffle import Waffle
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %pip install pywaffle

# %%
# Sample data
data = {'Low Income': 30, 'Low Food Access': 15, 'LILA': 5}

# Create the pictogram chart
fig = plt.figure(
    FigureClass=Waffle,
    rows=5,  # Number of rows in the waffle chart
    values=data,
    colors=["#4C8CB5", "#B7CBD7", "#C0C0C0"], # Colors for each category
    icons='user',  # Icon to use for the pictogram (e.g., 'star', 'user', 'heart' from Font Awesome)
    font_size=18,  # Size of the icons
    icon_legend=True, # Display a legend with icons
    legend={'labels': [f"{k}: {v}" for k, v in data.items()], 'loc': 'upper right', 'bbox_to_anchor': (0, -0.2)})

plt.title("Gradient Person Chart", fontsize=14)
plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>
